# %%
import pandas as pd
import numpy as np
df_1=pd.read_csv("official_house_data/114_2016_Q1.csv")
df_2=pd.read_csv("official_house_data/114_2016_Q2.csv")
df_3=pd.read_csv("official_house_data/114_2016_Q3.csv")
df_4=pd.read_csv("official_house_data/114_2016_Q4.csv")
df_5=pd.read_csv("official_house_data/115_2017_Q1.csv")
df_6=pd.read_csv("official_house_data/115_2017_Q2.csv")
df_propublica=pd.read_csv("official_house_data/2009Q3-house-disburse-detail.csv")

# %% [markdown]
# Normalize Header Names: [ORGANIZATION,PROGRAM,SORT_SUBTOTAL_DESCRIPTION,SORT_SEQUENCE,TRANSACTION_DATE,DATA SOURCE,DOCUMENT,VENDOR_NAME,PERFORM_START_DT,PERFORM_END_DT,DESCRIPTION,AMOUNT]

# %%
df_6.shape
# Out:
# (106137, 12)

# %%
df_all = pd.concat([df_1, df_2,df_3,df_4,df_5,df_6])

# %%
df_all
# Out:
#                                  ORGANIZATION                         PROGRAM  \
# 0                  2016 OFFICE OF THE SPEAKER  OFFICIAL EXPENSES - LEADERSHIP
# 1                  2016 OFFICE OF THE SPEAKER  OFFICIAL EXPENSES - LEADERSHIP
# 2                  2016 OFFICE OF THE SPEAKER  OFFICIAL EXPENSES - LEADERSHIP
# 3                  2016 OFFICE OF THE SPEAKER            GENERAL EXPENDITURES
# 4                  2016 OFFICE OF THE SPEAKER            GENERAL EXPENDITURES
# 5                  2016 OFFICE OF THE SPEAKER            GENERAL EXPENDITURES
# 6                  2016 OFFICE OF THE SPEAKER            GENERAL EXPENDITURES
# 7                  2016 OFFICE OF THE SPEAKER            GENERAL EXPENDITURES
# 8                  2016 OFFICE OF THE SPEAKER            GENERAL EXPENDITURES
# 9                  2016 OFFICE OF THE SPEAKER            GENERAL EXPENDITURES
# 10                 2016 OFFICE OF THE SPEAKER            GENERAL EXPENDITURES
# ...

# %%
df_all.shape
# Out:
# (635721, 12)

# %%
df_clean = df_all[df_all.SORT_SEQUENCE == "DETAIL"]

# %%
df_clean
# Out:
#                                     ORGANIZATION  \
# 0                     2016 OFFICE OF THE SPEAKER
# 3                     2016 OFFICE OF THE SPEAKER
# 4                     2016 OFFICE OF THE SPEAKER
# 5                     2016 OFFICE OF THE SPEAKER
# 6                     2016 OFFICE OF THE SPEAKER
# 7                     2016 OFFICE OF THE SPEAKER
# 8                     2016 OFFICE OF THE SPEAKER
# 9                     2016 OFFICE OF THE SPEAKER
# 10                    2016 OFFICE OF THE SPEAKER
# 11                    2016 OFFICE OF THE SPEAKER
# 12                    2016 OFFICE OF THE SPEAKER
# 13                    2016 OFFICE OF THE SPEAKER
# 14                    2016 OFFICE OF THE SPEAKER
# 15                    2016 OFFICE OF THE SPEAKER
# 16                    2016 OFFICE OF THE SPEAKER
# 17                    2016 OFFICE OF THE SPEAKER
# 18                    2016 OFFICE OF THE SPEAKER
# 19                    2016 OFFICE OF THE SPEAKER
# ...

# %%
df_propublica
# Out:
#        BIOGUIDE_ID                     OFFICE QUARTER  \
# 0              NaN             COMMUNICATIONS  2009Q3
# 1              NaN             COMMUNICATIONS  2009Q3
# 2              NaN             COMMUNICATIONS  2009Q3
# 3              NaN             COMMUNICATIONS  2009Q3
# 4              NaN             COMMUNICATIONS  2009Q3
# 5              NaN             COMMUNICATIONS  2009Q3
# 6              NaN             COMMUNICATIONS  2009Q3
# 7              NaN             COMMUNICATIONS  2009Q3
# 8              NaN             COMMUNICATIONS  2009Q3
# 9              NaN             COMMUNICATIONS  2009Q3
# 10             NaN             COMMUNICATIONS  2009Q3
# 11             NaN             COMMUNICATIONS  2009Q3
# 12             NaN             COMMUNICATIONS  2009Q3
# 13             NaN             COMMUNICATIONS  2009Q3
# 14             NaN             COMMUNICATIONS  2009Q3
# 15             NaN             COMMUNICATIONS  2009Q3
# ...

# %%
df_propublica = df2.SORT_SEQUENCE.unique()
