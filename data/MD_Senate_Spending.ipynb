# %%
import pandas as pd
import numpy as np
df1=pd.read_csv("114_sdoc7_senate_data.csv")

# %%
df1
# Out:
#       source_doc  senator_flag senator_name  \
# 0       114sdoc7             0          NaN
# 1       114sdoc7             0          NaN
# 2       114sdoc7             0          NaN
# 3       114sdoc7             0          NaN
# 4       114sdoc7             0          NaN
# 5       114sdoc7             0          NaN
# 6       114sdoc7             0          NaN
# 7       114sdoc7             0          NaN
# 8       114sdoc7             0          NaN
# 9       114sdoc7             0          NaN
# 10      114sdoc7             0          NaN
# 11      114sdoc7             0          NaN
# 12      114sdoc7             0          NaN
# 13      114sdoc7             0          NaN
# 14      114sdoc7             0          NaN
# 15      114sdoc7             0          NaN
# 16      114sdoc7             0          NaN
# 17      114sdoc7             0          NaN
# 18      114sdoc7             0          NaN
# 19      114sdoc7             0          NaN
# ...
